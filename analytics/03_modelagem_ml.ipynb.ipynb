# %%
# %pip install duckdb pandas scikit-learn pyarrow matplotlib seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 84.0 MB/s eta 0:00:0000:01:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import duckdb

# %%
con = duckdb.connect("../duckdb/lakehouse.duckdb")
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 con = duckdb.connect("../duckdb/lakehouse.duckdb")
#
# IOException: IO Error: Cannot open file "/workspace/duckdb/lakehouse.duckdb": No such file or directory
